# %%
import csv
fh = open('webl22.txt')
campaign_data = list(csv.reader(fh))

full_candidate_list = []
for candidate_data in campaign_data:
  for id_string in candidate_data:
    id_string = id_string.strip(' ')
    id_string = id_string.split('|')
    if len(id_string) == 2:
      id_string1 = id_string
    if len(id_string) > 2:
      candidate_list = list(id_string1 + id_string)
      full_candidate_list.append(candidate_list)
# 2D list where each list is an individual candidate's information

# isolating specific information from each candidate to create lists to set into DataFrame
cand_id_list = []
cand_name_list = []
cand_incumbent_challenger_status = []
cand_party_code = []
cand_party_affiliation = []
cand_total_reciepts = []
cand_transfers_from_authorized_committees = []
cand_total_disbursements = []
cand_transfers_to_authorized_committees = []
cand_beginning_cash = []
cand_ending_cash = []
cand_contributions_from_candidate = []
cand_loans_from_candidate = []
cand_other_loans = []
cand_loan_repayments = []
cand_other_loan_repayments = []
cand_debts_owed_by = []
cand_total_individual_contributions = []
cand_state = []
cand_district = []
cand_special_election_status = []
cand_primary_election_status = []
cand_runoff_election_status = []
cand_general_election_status = []
cand_general_election_percentage = []
cand_contributions_from_other_political_committees = []
cand_contributions_from_party_committees = []
cand_coverage_end_date = []
cand_refunds_to_individuals = []
cand_refunds_to_committees = []
for candidate in full_candidate_list:
  cand_id = candidate[0]
  cand_id_list.append(cand_id)
  cand_name = str(candidate[2] + ' ' + candidate[1])
  cand_name_list.append(cand_name)
  cand_ici = candidate[3]
  cand_incumbent_challenger_status.append(cand_ici)
  cand_party_code.append(candidate[4])
  cand_party_affiliation.append(candidate[5])
  cand_total_reciepts.append(candidate[6])
  cand_transfers_from_authorized_committees.append(candidate[7])
  cand_total_disbursements.append(candidate[8])
  cand_transfers_to_authorized_committees.append(candidate[9])
  cand_beginning_cash.append(candidate[10])
  cand_ending_cash.append(candidate[11])
  cand_contributions_from_candidate.append(candidate[12])
  cand_loans_from_candidate.append(candidate[13])
  cand_other_loans.append(candidate[14])
  cand_loan_repayments.append(candidate[15])
  cand_other_loan_repayments.append(candidate[16])
  cand_debts_owed_by.append(candidate[17])
  cand_total_individual_contributions.append(candidate[18])
  cand_state.append(candidate[19])
  cand_district.append(candidate[20])
  cand_special_election_status.append(candidate[21])
  cand_primary_election_status.append(candidate[22])
  cand_runoff_election_status.append(candidate[23])
  cand_general_election_status.append(candidate[24])
  cand_general_election_percentage.append(candidate[25])
  cand_contributions_from_other_political_committees.append(candidate[26])
  cand_contributions_from_party_committees.append(candidate[27])
  cand_coverage_end_date.append(candidate[28])
  cand_refunds_to_individuals.append(candidate[29])
  cand_refunds_to_committees.append(candidate[30])

# creating dataframe for visualizations
import pandas as pd
combined_list = []
for i in range(len(cand_id_list)):
  mini_row = []
  mini_row.append(cand_id_list[i])
  mini_row.append(cand_name_list[i])
  mini_row.append(cand_incumbent_challenger_status[i])
  mini_row.append(cand_party_code[i])
  mini_row.append(cand_party_affiliation[i])
  mini_row.append(cand_total_reciepts[i])
  mini_row.append(cand_transfers_from_authorized_committees[i])
  mini_row.append(cand_total_disbursements[i])
  mini_row.append(cand_transfers_to_authorized_committees[i])
  mini_row.append(cand_beginning_cash[i])
  mini_row.append(cand_ending_cash[i])
  mini_row.append(cand_contributions_from_candidate[i])
  mini_row.append(cand_loans_from_candidate[i])
  mini_row.append(cand_other_loans[i])
  mini_row.append(cand_loan_repayments[i])
  mini_row.append(cand_other_loan_repayments[i])
  mini_row.append(cand_debts_owed_by[i])
  mini_row.append(cand_total_individual_contributions[i])
  mini_row.append(cand_state[i])
  mini_row.append(cand_district[i])
  mini_row.append(cand_special_election_status[i])
  mini_row.append(cand_primary_election_status[i])
  mini_row.append(cand_runoff_election_status[i])
  mini_row.append(cand_general_election_status[i])
  mini_row.append(cand_general_election_percentage[i])
  mini_row.append(cand_contributions_from_other_political_committees[i])
  mini_row.append(cand_contributions_from_party_committees[i])
  mini_row.append(cand_coverage_end_date[i])
  mini_row.append(cand_refunds_to_individuals[i])
  mini_row.append(cand_refunds_to_committees[i])
  combined_list.append(mini_row)

df = pd.DataFrame(combined_list, columns=['ID', 'Name', 'Incumbent Challenger Status', 'Party Code', 'Party Affiliation', 'Total Reciepts', 'Transfers from Authorized Committees', 'Total Disbursements', 'Transfers to Authorized Committees', 'Beginning Cash', 'Ending Cash', 'Contributions from Candidate', 'Loans from Candidate', 'Other Loans', 'Candidate Loan Repayments', 'Other Loan Repayments', 'Debts Owed By', 'Total Individual Contributions', 'State', 'District', 'Special Election Status', 'Primary Election Status', 'Runoff Election Status', 'General Election Status', 'General Election Percentage', 'Contributions from Other Political Committees', 'Contributions from Party Committees', 'Coverage End Date', 'Refunds to Individuals', 'Refunds to Committees'])

print(df.head())
# Out:
#           ID                  Name Incumbent Challenger Status Party Code  \
# 0  H2AK00200  CHRISTOPHER CONSTANT                           C          1
# 1  H2AK01158          MARY PELTOLA                           I          1
# 2  H2AK01240           ADAM L WOOL                           O          1
# 3  H2AK00218     JOSHUA CARL REVAK                           O          2
# 4  H2AK00226           SARAH PALIN                           O          2
#
#   Party Affiliation Total Reciepts Transfers from Authorized Committees  \
# 0               DEM       164637.9                                    0
# 1               DEM     5785806.88                             144363.9
# 2               DEM       16217.07                                    0
# 3               REP         121841                                    0
# 4               REP     1742020.01                            112737.77
#
#   Total Disbursements Transfers to Authorized Committees Beginning Cash  ...  \
# ...

# %%
al_dono = 0
ak_dono = 0
az_dono = 0
ar_dono = 0
ca_dono = 0
co_dono = 0
ct_dono = 0
de_dono = 0
fl_dono = 0
ga_dono = 0
hi_dono = 0
id_dono = 0
il_dono = 0
in_dono = 0
ia_dono = 0
ks_dono = 0
ky_dono = 0
la_dono = 0
me_dono = 0
md_dono = 0
ma_dono = 0
mi_dono = 0
mn_dono = 0
ms_dono = 0
mo_dono = 0
mt_dono = 0
ne_dono = 0
nv_dono = 0
nh_dono = 0
nj_dono = 0
nm_dono = 0
ny_dono = 0
nc_dono = 0
nd_dono = 0
oh_dono = 0
ok_dono = 0
or_dono = 0
pa_dono = 0
ri_dono = 0
sc_dono = 0
sd_dono = 0
tn_dono = 0
tx_dono = 0
ut_dono = 0
vt_dono = 0
va_dono = 0
vi_dono = 0
wa_dono = 0
wv_dono = 0
wi_dono = 0
wy_dono = 0


for i in range(len(df)):
  if df['State'][i] == 'AL':
    al_dono = al_dono + float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'AK':
    ak_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'AZ':
    az_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'AR':
    ar_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'CA':
    ca_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'CO':
    co_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'CT':
    ct_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'DE':
    de_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'FL':
    fl_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'GA':
    ga_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'HI':
    hi_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'ID':
    id_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'IL':
    il_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'IN':
    in_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'IA':
    ia_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'KS':
    ks_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'KY':
    ky_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'LA':
    la_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'ME':
    me_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'MD':
    md_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'MA':
    ma_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'MI':
    mi_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'MS':
     ms_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'MO':
    mo_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'MT':
    mt_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'NE':
    ne_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'NV':
    nv_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'NH':
    nh_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'NJ':
    nj_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'NM':
    nm_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'NY':
    ny_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'NC':
    nc_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'ND':
    nd_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'OH':
    oh_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'OK':
    ok_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'OR':
    or_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'PA':
    pa_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'RI':
    ri_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'SC':
    sc_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'SD':
    sd_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'TN':
    tn_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'TX':
    tx_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'UT':
    ut_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'VT':
    vt_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'VA':
    va_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'VI':
    vi_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'WA':
    wa_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'WV':
    wv_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'WI':
    wi_dono += float(df['Total Individual Contributions'][i])
  if df['State'][i] == 'WY':
    wy_dono += float(df['Total Individual Contributions'][i])

total_state_dono_list = [al_dono,
ak_dono,
az_dono,
ar_dono,
ca_dono,
co_dono,
ct_dono,
de_dono,
fl_dono,
ga_dono,
hi_dono,
id_dono,
il_dono,
in_dono,
ia_dono,
ks_dono,
ky_dono,
la_dono,
me_dono,
md_dono,
ma_dono,
mi_dono,
mn_dono,
ms_dono,
mo_dono,
mt_dono,
ne_dono,
nv_dono,
nh_dono,
nj_dono,
nm_dono,
ny_dono,
nc_dono,
nd_dono,
oh_dono,
ok_dono,
or_dono,
pa_dono,
ri_dono,
sc_dono,
sd_dono,
tn_dono,
tx_dono,
ut_dono,
vt_dono,
va_dono,
wa_dono,
wv_dono,
wi_dono,
wy_dono]

print(total_state_dono_list)
# Out:
# [23256702.38, 19934141.490000002, 120004384.04999998, 8898036.27, 217667036.98000005, 50383894.59999999, 13636948.239999998, 1703317.8399999999, 254290325.35, 288689133.62000006, 2959281.69, 2714526.35, 64184737.000000015, 21314583.419999998, 40531037.690000005, 13489500.91, 35258431.43, 45276515.730000004, 7577853.119999999, 20039851.7, 10192666.940000001, 44375619.20999999, 0, 3926836.4500000007, 39930234.21999999, 12073800.77, 8793991.96, 72436174.55, 45191147.38000001, 40784580.460000016, 12464532.75, 141228318.09999996, 94807313.32000001, 2075077.5199999998, 108832178.06, 20429413.630000003, 26071170.650000002, 140519619.10999998, 7852310.29, 50201643.37, 6024034.3, 13001981.960000003, 89798170.36, 20686568.6, 6861684.619999999, 37512175.74999999, 58013829.32000001, 2839964.91, 78061559.58, 6090231.97]

# %%
al_dono
ak_dono
az_dono
ar_dono
ca_dono 
co_dono
ct_dono 
de_dono 
fl_dono 
ga_dono 
hi_dono 
id_dono 
il_dono 
in_dono 
ia_dono
ks_dono 
ky_dono 
la_dono 
me_dono 
md_dono 
ma_dono 
mi_dono 
mn_dono 
ms_dono 
mo_dono 
mt_dono 
ne_dono 
nv_dono 
nh_dono 
nj_dono 
nm_dono 
ny_dono 
nc_dono 
nd_dono 
oh_dono 
ok_dono 
or_dono 
pa_dono 
ri_dono 
sc_dono 
sd_dono 
tn_dono 
tx_dono 
ut_dono 
vt_dono 
va_dono 
vi_dono 
wa_dono 
wv_dono 
wi_dono 
wy_dono
# Out:
# 6090231.97

# %%
#2006

import csv
fh = open('weball06.txt')
campaign_data = list(csv.reader(fh))

full_candidate_list = []
for candidate_data in campaign_data:
  for id_string in candidate_data:
    id_string = id_string.strip(' ')
    id_string = id_string.split('|')
    if len(id_string) == 2:
      id_string1 = id_string
    if len(id_string) > 2:
      candidate_list = list(id_string1 + id_string)
      full_candidate_list.append(candidate_list)
# 2D list where each list is an individual candidate's information

# isolating specific information from each candidate to create lists to set into DataFrame
cand_id_list = []
cand_name_list = []
cand_incumbent_challenger_status = []
cand_party_code = []
cand_party_affiliation = []
cand_total_reciepts = []
cand_transfers_from_authorized_committees = []
cand_total_disbursements = []
cand_transfers_to_authorized_committees = []
cand_beginning_cash = []
cand_ending_cash = []
cand_contributions_from_candidate = []
cand_loans_from_candidate = []
cand_other_loans = []
cand_loan_repayments = []
cand_other_loan_repayments = []
cand_debts_owed_by = []
cand_total_individual_contributions = []
cand_state = []
cand_district = []
cand_special_election_status = []
cand_primary_election_status = []
cand_runoff_election_status = []
cand_general_election_status = []
cand_general_election_percentage = []
cand_contributions_from_other_political_committees = []
cand_contributions_from_party_committees = []
cand_coverage_end_date = []
cand_refunds_to_individuals = []
cand_refunds_to_committees = []

for candidate in full_candidate_list:
  if candidate[24] == "W":
    cand_id = candidate[0]
    cand_id_list.append(cand_id)
    cand_name = str(candidate[2] + ' ' + candidate[1])
    cand_name_list.append(cand_name)
    cand_ici = candidate[3]
    cand_incumbent_challenger_status.append(cand_ici)
    cand_party_code.append(candidate[4])
    cand_party_affiliation.append(candidate[5])
    cand_total_reciepts.append(candidate[6])
    cand_transfers_from_authorized_committees.append(candidate[7])
    cand_total_disbursements.append(candidate[8])
    cand_transfers_to_authorized_committees.append(candidate[9])
    cand_beginning_cash.append(candidate[10])
    cand_ending_cash.append(candidate[11])
    cand_contributions_from_candidate.append(candidate[12])
    cand_loans_from_candidate.append(candidate[13])
    cand_other_loans.append(candidate[14])
    cand_loan_repayments.append(candidate[15])
    cand_other_loan_repayments.append(candidate[16])
    cand_debts_owed_by.append(candidate[17])
    cand_total_individual_contributions.append(candidate[18])
    cand_state.append(candidate[19])
    cand_district.append(candidate[20])
    cand_special_election_status.append(candidate[21])
    cand_primary_election_status.append(candidate[22])
    cand_runoff_election_status.append(candidate[23])
    cand_general_election_status.append(candidate[24])
    cand_general_election_percentage.append(candidate[25])
    cand_contributions_from_other_political_committees.append(candidate[26])
    cand_contributions_from_party_committees.append(candidate[27])
    cand_coverage_end_date.append(candidate[28])
    cand_refunds_to_individuals.append(candidate[29])
    cand_refunds_to_committees.append(candidate[30])

# creating dataframe for visualizations
import pandas as pd
combined_list = []
for i in range(len(cand_id_list)):
  mini_row = []
  mini_row.append(cand_id_list[i])
  mini_row.append(cand_name_list[i])
  mini_row.append(cand_incumbent_challenger_status[i])
  mini_row.append(cand_party_code[i])
  mini_row.append(cand_party_affiliation[i])
  mini_row.append(cand_total_reciepts[i])
  mini_row.append(cand_transfers_from_authorized_committees[i])
  mini_row.append(cand_total_disbursements[i])
  mini_row.append(cand_transfers_to_authorized_committees[i])
  mini_row.append(cand_beginning_cash[i])
  mini_row.append(cand_ending_cash[i])
  mini_row.append(cand_contributions_from_candidate[i])
  mini_row.append(cand_loans_from_candidate[i])
  mini_row.append(cand_other_loans[i])
  mini_row.append(cand_loan_repayments[i])
  mini_row.append(cand_other_loan_repayments[i])
  mini_row.append(cand_debts_owed_by[i])
  mini_row.append(cand_total_individual_contributions[i])
  mini_row.append(cand_state[i])
  mini_row.append(cand_district[i])
  mini_row.append(cand_special_election_status[i])
  mini_row.append(cand_primary_election_status[i])
  mini_row.append(cand_runoff_election_status[i])
  mini_row.append(cand_general_election_status[i])
  mini_row.append(cand_general_election_percentage[i])
  mini_row.append(cand_contributions_from_other_political_committees[i])
  mini_row.append(cand_contributions_from_party_committees[i])
  mini_row.append(cand_coverage_end_date[i])
  mini_row.append(cand_refunds_to_individuals[i])
  mini_row.append(cand_refunds_to_committees[i])
  combined_list.append(mini_row)

winner_df = pd.DataFrame(combined_list, columns=['ID', 'Name', 'Incumbent Challenger Status', 'Party Code', 'Party Affiliation', 'Total Reciepts', 'Transfers from Authorized Committees', 'Total Disbursements', 'Transfers to Authorized Committees', 'Beginning Cash', 'Ending Cash', 'Contributions from Candidate', 'Loans from Candidate', 'Other Loans', 'Candidate Loan Repayments', 'Other Loan Repayments', 'Debts Owed By', 'Total Individual Contributions', 'State', 'District', 'Special Election Status', 'Primary Election Status', 'Runoff Election Status', 'General Election Status', 'General Election Percentage', 'Contributions from Other Political Committees', 'Contributions from Party Committees', 'Coverage End Date', 'Refunds to Individuals', 'Refunds to Committees'])
print(winner_df)
# Out:
#             ID                Name Incumbent Challenger Status Party Code  \
# 0    H6AK00045      DONALD E YOUNG                           I          2
# 1    H2AL01077           JO BONNER                           I          2
# 2    H2AL02067       TERRY EVERETT                           I          2
# 3    H2AL03032      MICHAEL ROGERS                           I          2
# 4    H6AL04098  ROBERT B. ADERHOLT                           I          2
# ..         ...                 ...                         ...        ...
# 459  S4VT00033     BERNARD SANDERS                           O          3
# 460  S8WA00194      MARIA CANTWELL                           I          1
# 461  S6WI00061           HERB KOHL                           I          1
# 462  S6WV00014       ROBERT C BYRD                           I          1
# 463  S4WY00055        CRAIG THOMAS                           I          2
#
#     Party Affiliation Total Reciepts Transfers from Authorized Committees  \
# ...

# %%
# Line graph of total campaign contributions

ind_contributions = []

#2006

import csv
fh = open('weball06.txt')
campaign_data = list(csv.reader(fh))

full_candidate_list = []
for candidate_data in campaign_data:
  for id_string in candidate_data:
    id_string = id_string.strip(' ')
    id_string = id_string.split('|')
    if len(id_string) == 2:
      id_string1 = id_string
    if len(id_string) > 2:
      candidate_list = list(id_string1 + id_string)
      full_candidate_list.append(candidate_list)

#sum total reciets
total_reciepts_2006 = 0
for candidate in full_candidate_list:
  total_reciepts_2006 = float(candidate[17]) + total_reciepts_2006
ind_contributions.append(round(total_reciepts_2006, ndigits = 2))

#2008

fh = open('weball08.txt')
campaign_data = list(csv.reader(fh))

full_candidate_list = []
for candidate_data in campaign_data:
  for id_string in candidate_data:
    id_string = id_string.strip(' ')
    id_string = id_string.split('|')
    if len(id_string) == 2:
      id_string1 = id_string
    if len(id_string) > 2:
      candidate_list = list(id_string1 + id_string)
      full_candidate_list.append(candidate_list)

#sum total reciets
total_reciepts_2008 = 0
for candidate in full_candidate_list:
  total_reciepts_2008 = float(candidate[17]) + total_reciepts_2008
ind_contributions.append(round(total_reciepts_2008, ndigits = 2))

#2010

fh = open('weball10.txt')
campaign_data = list(csv.reader(fh))

full_candidate_list = []
for candidate_data in campaign_data:
  for id_string in candidate_data:
    id_string = id_string.strip(' ')
    id_string = id_string.split('|')
    if len(id_string) == 2:
      id_string1 = id_string
    if len(id_string) > 2:
      candidate_list = list(id_string1 + id_string)
      full_candidate_list.append(candidate_list)

#sum total reciets
total_reciepts_2010 = 0
for candidate in full_candidate_list:
  total_reciepts_2010 = float(candidate[17]) + total_reciepts_2010
ind_contributions.append(round(total_reciepts_2010, ndigits = 2))

#2012

fh = open('weball12.txt')
campaign_data = list(csv.reader(fh))

full_candidate_list = []
for candidate_data in campaign_data:
  for id_string in candidate_data:
    id_string = id_string.strip(' ')
    id_string = id_string.split('|')
    if len(id_string) == 2:
      id_string1 = id_string
    if len(id_string) > 2:
      candidate_list = list(id_string1 + id_string)
      full_candidate_list.append(candidate_list)

#sum total reciets
total_reciepts_2012 = 0
for candidate in full_candidate_list:
  total_reciepts_2012 = float(candidate[17]) + total_reciepts_2012
ind_contributions.append(round(total_reciepts_2012, ndigits = 2))

#2014

fh = open('weball14.txt')
campaign_data = list(csv.reader(fh))

full_candidate_list = []
for candidate_data in campaign_data:
  for id_string in candidate_data:
    id_string = id_string.strip(' ')
    id_string = id_string.split('|')
    if len(id_string) == 2:
      id_string1 = id_string
    if len(id_string) > 2:
      candidate_list = list(id_string1 + id_string)
      full_candidate_list.append(candidate_list)


#sum total reciets
total_reciepts_2014 = 0
for candidate in full_candidate_list:
  total_reciepts_2014 = float(candidate[17]) + total_reciepts_2014
ind_contributions.append(round(total_reciepts_2014, ndigits = 2))

#2016

fh = open('weball16.txt')
campaign_data = list(csv.reader(fh))

full_candidate_list = []
for candidate_data in campaign_data:
  for id_string in candidate_data:
    id_string = id_string.strip(' ')
    id_string = id_string.split('|')
    if len(id_string) == 2:
      id_string1 = id_string
    if len(id_string) > 2:
      candidate_list = list(id_string1 + id_string)
      full_candidate_list.append(candidate_list)

#sum total reciets
total_reciepts_2016 = 0
for candidate in full_candidate_list:
  total_reciepts_2016 = float(candidate[17]) + total_reciepts_2016
ind_contributions.append(round(total_reciepts_2016, ndigits = 2))

#2018

fh = open('weball18.txt')
campaign_data = list(csv.reader(fh))

full_candidate_list = []
for candidate_data in campaign_data:
  for id_string in candidate_data:
    id_string = id_string.strip(' ')
    id_string = id_string.split('|')
    if len(id_string) == 2:
      id_string1 = id_string
    if len(id_string) > 2:
      candidate_list = list(id_string1 + id_string)
      full_candidate_list.append(candidate_list)


#sum total reciets
total_reciepts_2018 = 0
for candidate in full_candidate_list:
  total_reciepts_2018 = float(candidate[17]) + total_reciepts_2018
ind_contributions.append(round(total_reciepts_2018, ndigits = 2))

#2020

fh = open('weball20.txt')
campaign_data = list(csv.reader(fh))

full_candidate_list = []
for candidate_data in campaign_data:
  for id_string in candidate_data:
    id_string = id_string.strip(' ')
    id_string = id_string.split('|')
    if len(id_string) == 2:
      id_string1 = id_string
    if len(id_string) > 2:
      candidate_list = list(id_string1 + id_string)
      full_candidate_list.append(candidate_list)

#sum total reciets
total_reciepts_2020 = 0
for candidate in full_candidate_list:
  total_reciepts_2020 = float(candidate[17]) + total_reciepts_2020
ind_contributions.append(round(total_reciepts_2020, ndigits = 2))

#2022


fh = open('webl22.txt')
campaign_data = list(csv.reader(fh))

full_candidate_list = []
for candidate_data in campaign_data:
  for id_string in candidate_data:
    id_string = id_string.strip(' ')
    id_string = id_string.split('|')
    if len(id_string) == 2:
      id_string1 = id_string
    if len(id_string) > 2:
      candidate_list = list(id_string1 + id_string)
      full_candidate_list.append(candidate_list)

#sum total reciets
total_reciepts_2022 = 0
for candidate in full_candidate_list:
  total_reciepts_2022 = float(candidate[17]) + total_reciepts_2022
ind_contributions.append(round(total_reciepts_2022, ndigits = 2))

years = [2006, 2008, 2010, 2012, 2014, 2016, 2018, 2020, 2022]
print(years)
print(ind_contributions)

import pandas as pd
combined_list = []
for i in range(len(years)):
  mini_row = []
  mini_row.append(years[i])
  mini_row.append(ind_contributions[i])
  combined_list.append(mini_row)

ind_contrib_df = pd.DataFrame(combined_list, columns=['Year', 'Total Individual Contributions'])
print(ind_contrib_df)

import plotly.express as px

fig = px.line(ind_contrib_df, x="Year", y="Total Individual Contributions")
fig.show()

# embedding viz in html
fh = open('data_viz_1_by_contributions.html', 'w')
fh.close()
import plotly.io as pio
pio.write_html(fig, file='data_viz_1_by_contributions.html', auto_open=True, full_html=True)
# Out:
# [2006, 2008, 2010, 2012, 2014, 2016, 2018, 2020, 2022]
# [161401687.46, 167364898.86, 192124948.9, 193096357.63, 190776475.32, 170131553.99, 189666780.69, 246823063.03, 331057955.43]
#    Year  Total Individual Contributions
# 0  2006                    1.614017e+08
# 1  2008                    1.673649e+08
# 2  2010                    1.921249e+08
# 3  2012                    1.930964e+08
# 4  2014                    1.907765e+08
# 5  2016                    1.701316e+08
# 6  2018                    1.896668e+08
# 7  2020                    2.468231e+08
# 8  2022                    3.310580e+08
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
# ...

# %%
# Bar graph of total ind contributions  per party (dem v. rep) - 2022

total_rep = 0
total_dem = 0

for i in range(len(df)):
  if (df['Party Affiliation'][i]) == 'DEM':
    total_dem = total_dem + float(df['Total Individual Contributions'][i])
  if (df['Party Affiliation'][i]) == 'REP':
    total_rep = total_rep + float(df['Total Individual Contributions'][i])

print(total_rep)
print(total_dem)

party_donations_list = [['Democrat', total_dem], ['Republican', total_rep]]

import pandas as pd

party_dono_df = pd.DataFrame(party_donations_list, columns = ['Party', 'Total Individual Contributions'])

import plotly.express as px

fig = px.pie(party_dono_df, values = 'Total Individual Contributions', names = 'Party', title = 'Party Share of Individul Contributions')
fig.show()

# embedding viz in html
fh = open('data_viz_1_by_party.html', 'w')
fh.close()
import plotly.io as pio
pio.write_html(fig, file='data_viz_1_by_party.html', auto_open=True, full_html=True)
# Out:
# 996180452.0199999
# 1461639981.9100015
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# %%file political_party_of_states.csv
# State, Party
# AZ, DEM
# AL, REP
# AK, REP
# AR, REP
# CA, DEM
# CO, DEM
# CT, DEM
# DE, DEM
# FL, REP
# GA, DEM
# HI, DEM
# ID, REP
# IL, DEM
# IN, REP
# IA, REP
# KS, REP
# KY, REP
# LA, REP
# ME, DEM
# MD, DEM
# MA, DEM
# MI, DEM
# MN, DEM
# MS, REP
# MO, REP
# MT, REP
# NE, REP
# NV, DEM
# NH, DEM
# NJ, DEM
# NM, DEM
# NY, DEM
# NC, REP
# ND, REP
# OH, REP
# OK, REP
# OR, DEM
# PA, DEM
# RI, DEM
# SC, REP
# SD, REP
# TN, REP
# TX, REP
# UT, REP
# VT, DEM
# VA, DEM
# WA, DEM
# WV, REP
# WI, DEM
# WY, REP
# Out:
# Writing political_party_of_states.csv

# %%
import csv

fh = open('political_party_of_states.csv')
party_data = list(csv.reader(fh))
fh.close()

clean_party_data = []
for state in party_data:
  if state != party_data[0]:
    clean_party_data.append(state)

print(clean_party_data)

import pandas as pd

state_party_df = pd.DataFrame(clean_party_data, columns = ['State', 'Party'])
state_party_df['Total Individual Contributions'] = total_state_dono_list

fig = px.choropleth(state_party_df, locations='State', locationmode = 'USA-states', color = 'Party', scope = 'usa', title = 'State Party Affiliation (based on 2020 elcectoral votes)')
fig.show()

# embedding viz in html
fh = open('data_viz_2_by_party.html', 'w')
fh.close()
import plotly.io as pio
pio.write_html(fig, file='data_viz_2_by_party.html', auto_open=True, full_html=True)

fig2 = px.choropleth(state_party_df, locations='State', locationmode = 'USA-states', color = 'Total Individual Contributions', scope = 'usa', color_continuous_scale=px.colors.sequential.Viridis, title = 'Concentration of Contributions 2022')
fig2.show()

# embedding viz in html
fh = open('data_viz_2_by_contributions.html', 'w')
fh.close()
import plotly.io as pio
pio.write_html(fig2, file='data_viz_2_by_contributions.html', auto_open=True, full_html=True)
# Out:
# [['AZ', ' DEM'], ['AL', ' REP'], ['AK', ' REP'], ['AR', ' REP'], ['CA', ' DEM'], ['CO', ' DEM'], ['CT', ' DEM'], ['DE', ' DEM'], ['FL', ' REP'], ['GA', ' DEM'], ['HI', ' DEM'], ['ID', ' REP'], ['IL', ' DEM'], ['IN', ' REP'], ['IA', ' REP'], ['KS', ' REP'], ['KY', ' REP'], ['LA', ' REP'], ['ME', ' DEM'], ['MD', ' DEM'], ['MA', ' DEM'], ['MI', ' DEM'], ['MN', ' DEM'], ['MS', ' REP'], ['MO', ' REP'], ['MT', ' REP'], ['NE', ' REP'], ['NV', ' DEM'], ['NH', ' DEM'], ['NJ', ' DEM'], ['NM', ' DEM'], ['NY', ' DEM'], ['NC', ' REP'], ['ND', ' REP'], ['OH', ' REP'], ['OK', ' REP'], ['OR', ' DEM'], ['PA', ' DEM'], ['RI', ' DEM'], ['SC', ' REP'], ['SD', ' REP'], ['TN', ' REP'], ['TX', ' REP'], ['UT', ' REP'], ['VT', ' DEM'], ['VA', ' DEM'], ['WA', ' DEM'], ['WV', ' REP'], ['WI', ' DEM'], ['WY', ' REP']]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
# ...

# %%
# Histogram of candidate results and total donations
import plotly.express as px
fig = px.histogram(winner_df, x="Name", y = "Total Individual Contributions", title = '2006 Winner Donations')
fig.show()

# I know this seems like a somewhat useless graph because its too many names, but the person with the by far the most is Hillary Clinton so maybe we can say something about that
# embedding viz in html
fh = open('data_viz_1_by_winners.html', 'w')
fh.close()
import plotly.io as pio
pio.write_html(fig, file='data_viz_1_by_winners.html', auto_open=True, full_html=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Histogram of candidate results and total donations
import plotly.express as px
fig = px.histogram(state_party_df, x="State", y = "Total Individual Contributions", color = 'Party', title = 'Contributions by State and Winning Party')
fig.show()

# embedding viz in html
fh = open('data_viz_2_by_winners.html', 'w')
fh.close()
import plotly.io as pio
pio.write_html(fig, file='data_viz_2_by_winners.html', auto_open=True, full_html=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
